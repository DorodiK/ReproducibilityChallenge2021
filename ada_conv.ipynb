# %% [markdown]
# <a href="https://colab.research.google.com/github/DorodiK/ReproducibilityChallenge2021/blob/main/ada_conv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importing libraries

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd 'gdrive/My Drive/ada-conv-pytorch-master'
# Out:
# /content/gdrive/My Drive/ada-conv-pytorch-master

# %%
# !pip install git+https://github.com/PyTorchLightning/pytorch-lightning
import pytorch_lightning as pl
print(pl.__version__)

# %%
# !pip install torchinfo

# %%
# !python stylize.py -h
# Out:
# usage: stylize.py [-h] [--content CONTENT] [--style STYLE] [--output OUTPUT]
#                   [--model MODEL]
#
# optional arguments:
#   -h, --help         show this help message and exit
#   --content CONTENT
#   --style STYLE
#   --output OUTPUT
#   --model MODEL

# %% [markdown]
# ## AdaConv Experiments
#
# ### 1. Experiment with bold features for style image

# %%
# !python stylize.py --content '/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/content/content_01.jpg' --style '/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/style/style_06.png' --output '/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/output_compare1.png' --model model.ckpt
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:03<00:00, 156MB/s]

# %%
#Importing Libraries 
import cv2  
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img5 = cv2.imread('/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/output_compare1.png')
img5 = np.float32(img5)
cv2_imshow(img5)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F5AC3F9E1D0>

# %%
# !python stylize.py --content '/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/content/content_01.jpg' --style '/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/style/color.png' --output '/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/output_compare2.png' --model model.ckpt

# %%
img6 = cv2.imread('/content/gdrive/MyDrive/ada-conv-pytorch-master/test_images/output_compare2.png')
img6 = np.float32(img6)
cv2_imshow(img6)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F5ABACB85D0>
